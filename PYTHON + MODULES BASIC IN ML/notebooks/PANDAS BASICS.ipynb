# %% [markdown]
# PANDAS
#
# USED FOR DATA PREPROCESSING AND ANALYSIS

# %% [markdown]
# PANDAS DATA FRAME:
#
# pandas data-frame is a two - dimensional tabular data structure with labeled axes(rows and columns)

# %% [markdown]
# DATASET USED - housing.csv

# %%
import pandas as pd

# %% [markdown]
# Creating a pandas data frame

# %%
# importing the california housing price data
from sklearn.datasets import fetch_california_housing

housing_dataset = fetch_california_housing()

# %%
type(housing_dataset)
# Out:
# sklearn.utils._bunch.Bunch

# %%
print(housing_dataset)
# Out:
# {'data': array([[   8.3252    ,   41.        ,    6.98412698, ...,    2.55555556,
#           37.88      , -122.23      ],
#        [   8.3014    ,   21.        ,    6.23813708, ...,    2.10984183,
#           37.86      , -122.22      ],
#        [   7.2574    ,   52.        ,    8.28813559, ...,    2.80225989,
#           37.85      , -122.24      ],
#        ...,
#        [   1.7       ,   17.        ,    5.20554273, ...,    2.3256351 ,
#           39.43      , -121.22      ],
#        [   1.8672    ,   18.        ,    5.32951289, ...,    2.12320917,
#           39.43      , -121.32      ],
#        [   2.3886    ,   16.        ,    5.25471698, ...,    2.61698113,
# ...

# %%
# pandas dataframe

df_housing = pd.DataFrame(housing_dataset.data, columns=housing_dataset.feature_names)

# to print first 5 lines of dataset
df_housing.head()
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2  7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3  5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4  3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
#
#    Longitude
# 0    -122.23
# 1    -122.22
# 2    -122.24
# 3    -122.25
# 4    -122.25

# %%
df_housing.shape
# Out:
# (20640, 8)

# %% [markdown]
# IMPORTING A DATA FROM CSV FILE TO PANDAS DATA FRAME

# %%
# csv file to data frame

diabetes_df = pd.read_csv('diabetes.csv')

# %%
type(diabetes_df)
# Out:
# pandas.core.frame.DataFrame

# %%
diabetes_df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
diabetes_df.shape
# Out:
# (768, 9)

# %% [markdown]
# LOADING DATA FROM EXCEL TO DATA FRAME
#
# pd.raad_excel(' file path ')

# %% [markdown]
# EXPORTING A DATA FRAME TO A CSV FILE

# %%
df_housing.to_csv('housing.csv')

# %% [markdown]
# EXPORTING A DATA FRAME TO EXCEL FILE
#
# df.to_excel(' file name ')

# %%
# creating a data frame with random values

import numpy as np

random_df = pd.DataFrame(np.random.rand(20,10))

# %%
random_df.head()
# Out:
#           0         1         2         3         4         5         6  \
# 0  0.751286  0.346754  0.027945  0.439967  0.201602  0.359645  0.612556
# 1  0.316865  0.257314  0.301102  0.115383  0.927607  0.183191  0.495318
# 2  0.813277  0.216362  0.907838  0.635133  0.241931  0.338525  0.300412
# 3  0.022939  0.845535  0.179244  0.292518  0.310661  0.896863  0.971859
# 4  0.126320  0.648501  0.951099  0.033447  0.521131  0.476521  0.295591
#
#           7         8         9
# 0  0.318603  0.475685  0.735069
# 1  0.600944  0.311813  0.132666
# 2  0.756992  0.462530  0.282199
# 3  0.632273  0.584588  0.646439
# 4  0.818623  0.440119  0.797999

# %%
print(random_df)
# Out:
#            0         1         2         3         4         5         6  \
# 0   0.751286  0.346754  0.027945  0.439967  0.201602  0.359645  0.612556
# 1   0.316865  0.257314  0.301102  0.115383  0.927607  0.183191  0.495318
# 2   0.813277  0.216362  0.907838  0.635133  0.241931  0.338525  0.300412
# 3   0.022939  0.845535  0.179244  0.292518  0.310661  0.896863  0.971859
# 4   0.126320  0.648501  0.951099  0.033447  0.521131  0.476521  0.295591
# 5   0.550311  0.297160  0.054280  0.067163  0.240404  0.383182  0.958998
# 6   0.490588  0.155468  0.298699  0.327210  0.297637  0.429544  0.451472
# 7   0.502012  0.035920  0.942113  0.859355  0.357789  0.367924  0.142523
# 8   0.412566  0.488997  0.389111  0.950169  0.597418  0.034366  0.269773
# 9   0.784256  0.045393  0.581856  0.665674  0.207996  0.624525  0.732216
# 10  0.687452  0.623012  0.570991  0.293119  0.210531  0.962574  0.531931
# 11  0.092044  0.672038  0.680809  0.768434  0.107709  0.821361  0.558931
# ...

# %%
random_df.shape
# Out:
# (20, 10)

# %% [markdown]
# INSPECTING A DATAFRAME

# %%
# finding no. of rows and columns

df_housing.shape
# Out:
# (20640, 8)

# %%
# first 5 rows

df_housing.head()
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2  7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3  5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4  3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
#
#    Longitude
# 0    -122.23
# 1    -122.22
# 2    -122.24
# 3    -122.25
# 4    -122.25

# %%
# last 5 rows

df_housing.tail()
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 20635  1.5603      25.0  5.045455   1.133333       845.0  2.560606     39.48
# 20636  2.5568      18.0  6.114035   1.315789       356.0  3.122807     39.49
# 20637  1.7000      17.0  5.205543   1.120092      1007.0  2.325635     39.43
# 20638  1.8672      18.0  5.329513   1.171920       741.0  2.123209     39.43
# 20639  2.3886      16.0  5.254717   1.162264      1387.0  2.616981     39.37
#
#        Longitude
# 20635    -121.09
# 20636    -121.21
# 20637    -121.22
# 20638    -121.32
# 20639    -121.24

# %%
# informations about data frame
df_housing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   MedInc      20640 non-null  float64
#  1   HouseAge    20640 non-null  float64
#  2   AveRooms    20640 non-null  float64
#  3   AveBedrms   20640 non-null  float64
#  4   Population  20640 non-null  float64
#  5   AveOccup    20640 non-null  float64
#  6   Latitude    20640 non-null  float64
#  7   Longitude   20640 non-null  float64
# dtypes: float64(8)
# memory usage: 1.3 MB

# %%
# finding no. of missing values in each column

df_housing.isnull().sum()
# Out:
# MedInc        0
# HouseAge      0
# AveRooms      0
# AveBedrms     0
# Population    0
# AveOccup      0
# Latitude      0
# Longitude     0
# dtype: int64

# %%
diabetes_df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
# counting values based on labels

# syntax ----> df_variable.value_counts(" column name ")
diabetes_df.value_counts('Outcome')
# Out:
# Outcome
# 0    500
# 1    268
# Name: count, dtype: int64

# %%
# group the values based on mean

diabetes_df.groupby('Outcome').mean()
# Out:
#          Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# Outcome
# 0           3.298000  109.980000      68.184000      19.664000   68.792000
# 1           4.865672  141.257463      70.824627      22.164179  100.335821
#
#                BMI  DiabetesPedigreeFunction        Age
# Outcome
# 0        30.304200                  0.429734  31.190000
# 1        35.142537                  0.550500  37.067164

# %% [markdown]
# STATISTICAL MEASURES

# %%
# count or no. of values

df_housing.count()
# Out:
# MedInc        20640
# HouseAge      20640
# AveRooms      20640
# AveBedrms     20640
# Population    20640
# AveOccup      20640
# Latitude      20640
# Longitude     20640
# dtype: int64

# %%
# mean value column wise

df_housing.mean()
# Out:
# MedInc           3.870671
# HouseAge        28.639486
# AveRooms         5.429000
# AveBedrms        1.096675
# Population    1425.476744
# AveOccup         3.070655
# Latitude        35.631861
# Longitude     -119.569704
# dtype: float64

# %%
# standard deviation column wise

df_housing.std()
# Out:
# MedInc           1.899822
# HouseAge        12.585558
# AveRooms         2.474173
# AveBedrms        0.473911
# Population    1132.462122
# AveOccup        10.386050
# Latitude         2.135952
# Longitude        2.003532
# dtype: float64

# %%
# minimum value in each column

df_housing.min()
# Out:
# MedInc          0.499900
# HouseAge        1.000000
# AveRooms        0.846154
# AveBedrms       0.333333
# Population      3.000000
# AveOccup        0.692308
# Latitude       32.540000
# Longitude    -124.350000
# dtype: float64

# %%
# maximum value in each column

df_housing.max()
# Out:
# MedInc           15.000100
# HouseAge         52.000000
# AveRooms        141.909091
# AveBedrms        34.066667
# Population    35682.000000
# AveOccup       1243.333333
# Latitude         41.950000
# Longitude      -114.310000
# dtype: float64

# %%
# all statistical measures about the data frame

df_housing.describe()
# Out:
#              MedInc      HouseAge      AveRooms     AveBedrms    Population  \
# count  20640.000000  20640.000000  20640.000000  20640.000000  20640.000000
# mean       3.870671     28.639486      5.429000      1.096675   1425.476744
# std        1.899822     12.585558      2.474173      0.473911   1132.462122
# min        0.499900      1.000000      0.846154      0.333333      3.000000
# 25%        2.563400     18.000000      4.440716      1.006079    787.000000
# 50%        3.534800     29.000000      5.229129      1.048780   1166.000000
# 75%        4.743250     37.000000      6.052381      1.099526   1725.000000
# max       15.000100     52.000000    141.909091     34.066667  35682.000000
#
#            AveOccup      Latitude     Longitude
# count  20640.000000  20640.000000  20640.000000
# mean       3.070655     35.631861   -119.569704
# std       10.386050      2.135952      2.003532
# min        0.692308     32.540000   -124.350000
# ...

# %% [markdown]
# MANIPULATING A DATAFRAME

# %%
# adding a new column

df_housing['Price'] = housing_dataset.target

# %%
df_housing.head()
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2  7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3  5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4  3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
#
#    Longitude  Price
# 0    -122.23  4.526
# 1    -122.22  3.585
# 2    -122.24  3.521
# 3    -122.25  3.413
# 4    -122.25  3.422

# %%
# remove a particular roe

df_housing.drop(index = 0, axis = 0)
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 1      8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2      7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3      5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4      3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
# 5      4.0368      52.0  4.761658   1.103627       413.0  2.139896     37.85
# ...       ...       ...       ...        ...         ...       ...       ...
# 20635  1.5603      25.0  5.045455   1.133333       845.0  2.560606     39.48
# 20636  2.5568      18.0  6.114035   1.315789       356.0  3.122807     39.49
# 20637  1.7000      17.0  5.205543   1.120092      1007.0  2.325635     39.43
# 20638  1.8672      18.0  5.329513   1.171920       741.0  2.123209     39.43
# 20639  2.3886      16.0  5.254717   1.162264      1387.0  2.616981     39.37
#
#        Longitude  Price
# ...

# %%
# droping a column

df_housing.drop(columns = 'Latitude', axis = 1)
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Longitude  \
# 0      8.3252      41.0  6.984127   1.023810       322.0  2.555556    -122.23
# 1      8.3014      21.0  6.238137   0.971880      2401.0  2.109842    -122.22
# 2      7.2574      52.0  8.288136   1.073446       496.0  2.802260    -122.24
# 3      5.6431      52.0  5.817352   1.073059       558.0  2.547945    -122.25
# 4      3.8462      52.0  6.281853   1.081081       565.0  2.181467    -122.25
# ...       ...       ...       ...        ...         ...       ...        ...
# 20635  1.5603      25.0  5.045455   1.133333       845.0  2.560606    -121.09
# 20636  2.5568      18.0  6.114035   1.315789       356.0  3.122807    -121.21
# 20637  1.7000      17.0  5.205543   1.120092      1007.0  2.325635    -121.22
# 20638  1.8672      18.0  5.329513   1.171920       741.0  2.123209    -121.32
# 20639  2.3886      16.0  5.254717   1.162264      1387.0  2.616981    -121.24
#
#        Price
# 0      4.526
# ...

# %%
# locating a row using a index value

df_housing.iloc[2]
# Out:
# MedInc          7.257400
# HouseAge       52.000000
# AveRooms        8.288136
# AveBedrms       1.073446
# Population    496.000000
# AveOccup        2.802260
# Latitude       37.850000
# Longitude    -122.240000
# Price           3.521000
# Name: 2, dtype: float64

# %%
# locating a particular column

print(df_housing.iloc[:,0]) # first column of data frame
print(df_housing.iloc[:,1]) # second column of data frame
print(df_housing.iloc[:,2]) # third column of data frame
print(df_housing.iloc[:,-1]) # last column of data frame
# Out:
# 0        8.3252
# 1        8.3014
# 2        7.2574
# 3        5.6431
# 4        3.8462
#           ...
# 20635    1.5603
# 20636    2.5568
# 20637    1.7000
# 20638    1.8672
# 20639    2.3886
# Name: MedInc, Length: 20640, dtype: float64
# 0        41.0
# 1        21.0
# 2        52.0
# 3        52.0
# 4        52.0
#          ...
# 20635    25.0
# 20636    18.0
# 20637    17.0
# 20638    18.0
# 20639    16.0
# Name: HouseAge, Length: 20640, dtype: float64
# 0        6.984127
# 1        6.238137
# 2        8.288136
# 3        5.817352
# 4        6.281853
#            ...
# 20635    5.045455
# 20636    6.114035
# 20637    5.205543
# 20638    5.329513
# 20639    5.254717
# Name: AveRooms, Length: 20640, dtype: float64
# 0        4.526
# 1        3.585
# 2        3.521
# 3        3.413
# 4        3.422
#          ...
# 20635    0.781
# 20636    0.771
# 20637    0.923
# 20638    0.847
# 20639    0.894
# Name: Price, Length: 20640, dtype: float64

# %% [markdown]
# CORRELATION

# %%
df_housing.corr()
# Out:
#               MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  \
# MedInc      1.000000 -0.119034  0.326895  -0.062040    0.004834  0.018766
# HouseAge   -0.119034  1.000000 -0.153277  -0.077747   -0.296244  0.013191
# AveRooms    0.326895 -0.153277  1.000000   0.847621   -0.072213 -0.004852
# AveBedrms  -0.062040 -0.077747  0.847621   1.000000   -0.066197 -0.006181
# Population  0.004834 -0.296244 -0.072213  -0.066197    1.000000  0.069863
# AveOccup    0.018766  0.013191 -0.004852  -0.006181    0.069863  1.000000
# Latitude   -0.079809  0.011173  0.106389   0.069721   -0.108785  0.002366
# Longitude  -0.015176 -0.108197 -0.027540   0.013344    0.099773  0.002476
# Price       0.688075  0.105623  0.151948  -0.046701   -0.024650 -0.023737
#
#             Latitude  Longitude     Price
# MedInc     -0.079809  -0.015176  0.688075
# HouseAge    0.011173  -0.108197  0.105623
# AveRooms    0.106389  -0.027540  0.151948
# AveBedrms   0.069721   0.013344 -0.046701
# ...
